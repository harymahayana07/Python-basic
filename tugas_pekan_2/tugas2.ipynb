# %% [markdown]
# ##### Import Library Pendukung

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Import Data Csv
# ###### Data Tugas 2 : Data Handphone

# %%
df = pd.read_csv("Data/Soal_Tugas2.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ##### Check Data Kosong
# ###### Outputnya 0 artinya Semua Data lengkap tidak ada yang kosong

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_class      0
# dtype: int64

# %% [markdown]
# ##### Check Column/Variabel Data
# ###### Outputnya Nama-nama Colomn

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_class'],
#       dtype='object')

# %% [markdown]
# ##### Korelasi Antar Variabel
# ###### Berdasarkan Output dibawah : Korelasi Yang bernilai Positif artinya hubungan yang berbanding lurus atau bisa kita bilang berhubungan yang dimana hubungan antar variabel satu akan diikuti perubahan pada variabel dua secara teratur dan terarah. contohnya yang terlihat jelas adalah variabel Ram dengan variabel Price-list berkorelasi positif(Berhubungan yang dimana dengan tingginya Variabel Ram akan meningkatkan variabel price-list-nya.). untuk korelasi yang bernilai negatif adalah variabel yang berlawanan atau bisa dibilang tidak berhubungan. contohnya variabel dual_sim tinggi maka variabel battery_power akan cenderung rendah/ menurun.

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %% [markdown]
# ##### Insight Menarik

# %%
df[df.price_class >0]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 6              1821     0          1.7         0   4       1          10
# 10              769     1          2.9         1   0       0           9
# ...             ...   ...          ...       ...  ..     ...         ...
# 1993           1467     1          0.5         0   0       0          18
# 1994            858     0          2.2         0   1       0          50
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
df[(df.ram > 3000)]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 6              1821     0          1.7         0   4       1          10
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# 16              838     0          0.5         0   1       1          13
# 17              595     0          0.9         1   7       1          23
# ...             ...   ...          ...       ...  ..     ...         ...
# 1991           1882     0          2.0         0  11       1          44
# 1993           1467     1          0.5         0   0       0          18
# 1994            858     0          2.2         0   1       0          50
# 1997           1911     0          0.9         1   1       1          36
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df[(df.dual_sim > 0)]
df[df.dual_sim==0].sort_values("price_class",ascending=False)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 3               615     1          2.5         0   0       0          10
# 1234            578     1          0.5         0   9       1          62
# 1354           1998     1          1.2         0   8       0          31
# 1345            947     1          0.5         0   1       1          51
# 1340           1469     0          0.5         0   3       1          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 1987            618     1          1.0         0   9       1          13
# 1988           1547     1          2.9         0   2       0          57
# 1989            586     0          2.8         0   2       0          15
# 1990           1617     1          2.4         0   8       1          36
# 1998           1512     0          0.9         0   4       1          46
#
#       m_dep  mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %% [markdown]
# ##### Binning Data

# %%
df3=df
df3["Battery_Power_Grade"] = pd.cut(df3.battery_power, bins=[0,501,1000,1500,1998],
                      labels=['Rendah','lumayan','Tinggi','Sangat Tinggi'])
df3.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  sc_h  sc_w  talk_time  three_g  touch_screen  \
# 0        188        2  ...     9     7         19        0             0
# 1        136        3  ...    17     3          7        1             1
# 2        145        5  ...    11     2          9        1             1
# 3        131        6  ...    16     8         11        1             0
# 4        141        2  ...     8     2         15        1             1
#
#    wifi  price_class  Price_Grade  Battery_Power_Grade  False
# ...

# %%
df3["touch_screen"] = df3["touch_screen"].replace(to_replace=np.nan, value=11)
df3["touch_screen"] = df3["touch_screen"].replace(to_replace=[1], value=12)
print(df3["touch_screen"])
x=df3["touch_screen"] = pd.cut(df3.touch_screen, bins=[0,11,12],labels=['Jelek','Bagus'])
print(x)
# Out:
# 0       Jelek
# 1       Jelek
# 2       Jelek
# 3         NaN
# 4       Jelek
#         ...
# 1995    Jelek
# 1996    Jelek
# 1997    Jelek
# 1998    Jelek
# 1999    Jelek
# Name: touch_screen, Length: 2000, dtype: category
# Categories (2, object): ['Jelek' < 'Bagus']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\xampp\htdocs\sanbercode\tugas2sanber\tugas2.ipynb Cell 17 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/sanbercode/tugas2sanber/tugas2.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> df3["touch_screen"] = df3["touch_screen"].replace(to_replace=[1], value=12)
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/sanbercode/tugas2sanber/tugas2.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> print(df3["touch_screen"])
# ...
